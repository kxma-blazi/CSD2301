# %% [markdown]
# <a href="https://colab.research.google.com/github/kuma-gif/forCSD2301/blob/main/mySuccess01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **ทำในห้อง**

# %% [markdown]
# ![3-s2.0-B9780123944252000083-f08-04-9780123944252.jpg](data:image/jpeg;base64,...)

# %%
# เรียก libralie จัดการข้อมูล เเต่ใน Class นี้ใช้สำหรับ import Data เข้ามาเท่านั้น
import pandas as pd

# %%
# สร้างข้อมูลเป็น Dictionary
data = {   'ID':                ['MD12', 'MD13', 'MD14', 'MD15',],
    'Sales ID':        [12345, 23324, 57657, 65461,],
    'Finance ID':     ['C5729', 'LA781', 'J7301', 'K8839',],
    'Name':            ['Young', 'Stills', 'Furay', 'Palmer',],
    'Initials':           ['N', 'S', 'R', 'B', ],
    'City':               ['San Francisco', 'New Orleans', 'Yellow Springs', 'New York', ],
    'State':             ['CA', 'LA', 'OH', 'NY', '...'],
    'Email address': ['young@xyz.com', 'stil@stil.org', 'buf@spring.com', 'bass@spring.com'],
    'Balance':          [100, 200, 150, 200, ]
}

# %%
data
# Out:
# {'ID': ['MD12', 'MD13', 'MD14', 'MD15', '...'],
#  'Sales ID': [12345, 23324, 57657, 65461, '...'],
#  'Finance ID': ['C5729', 'LA781', 'J7301', 'K8839', '...'],
#  'Name': ['Young', 'Stills', 'Furay', 'Palmer', '...'],
#  'Initials': ['N', 'S', 'R', 'B', '...'],
#  'City': ['San Francisco', 'New Orleans', 'Yellow Springs', 'New York', '...'],
#  'State': ['CA', 'LA', 'OH', 'NY', '...'],
#  'Email address': ['young@xyz.com',
#   'stil@stil.org',
#   'buf@spring.com',
#   'bass@spring.com',
#   '...'],
#  'Balance': [100, 200, 150, 200, '...']}

# %%
# สร้าง dataframe
df = pd.DataFrame(data=data)

# %%
# เเสดง dataframe
df
# Out:
#      ID Sales ID Finance ID    Name Initials            City State  \
# 0  MD12    12345      C5729   Young        N   San Francisco    CA
# 1  MD13    23324      LA781  Stills        S     New Orleans    LA
# 2  MD14    57657      J7301   Furay        R  Yellow Springs    OH
# 3  MD15    65461      K8839  Palmer        B        New York    NY
# 4   ...      ...        ...     ...      ...             ...   ...
#
#      Email address Balance
# 0    young@xyz.com     100
# 1    stil@stil.org     200
# 2   buf@spring.com     150
# 3  bass@spring.com     200
# 4              ...     ...
